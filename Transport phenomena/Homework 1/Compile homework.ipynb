# %%
# %%bash
# jupyter nbconvert 'Homework 1.ipynb' --to latex --template bibliography_extension.tplx
# latex 'Homework 1.tex'
# bibtex 'Homework 1.aux'
# pdflatex 'Homework 1.tex'
# Out:
# This is pdfTeX, Version 3.1415926-2.5-1.40.14 (MiKTeX 2.9 64-bit)
# entering extended mode
#
# ("C:\Users\Nastac\Documents\MikkoKarkkainen\School\Transport phenomena\Homework
#  1\Homework 1.tex"
# LaTeX2e <2016/03/31> patch level 3
# Babel <3.9r> and hyphenation patterns for 69 language(s) loaded.
# ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\article.cls"
# Document Class: article 2014/09/29 v1.4h Standard LaTeX document class
# ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\size11.clo")
# ) ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\fontenc.st
# y" ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\base\t1enc.def
# "))
# ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\psnfss\mathpazo.s
# ty")
# ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\graphics\graphicx
# .sty"
# ("C:\Users\Nastac\AppData\Local\Programs\MiKTeX 2.9\tex\latex\graphics\keyval.s
# ty")
# ...
